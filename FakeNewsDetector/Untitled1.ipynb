# %%
from tensorflow import keras

# %%
import pandas as pd

# %%
data = pd.read_csv('fakenew.csv')

# %%
data.head()
# Out:
#                                                 text  label
# 0  Covid-19 masks are dangerous and the obligatio...  False
# 1  Thousands of people demonstrate in Romania aga...  False
# 2  The Argentine Vice President, Cristina Fernánd...  False
# 3  Fernando Simón, director of the Center for the...  False
# 4  News from the newspaper ‘El País’ in the year ...  False

# %%
data.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
labels=data.label
labels.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: label, dtype: bool

# %%
label = [0]*len(labels) 
for i in range(len(labels)):
    if labels[i] == False:
        label[i] = 'FAKE'
    else:
        label[i] = 'REAL'

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=train_test_split(data['text'], label, test_size=0.2, random_state=7)

# %%
type(x_train)
# Out:
# pandas.core.series.Series

# %%
y_train
# Out:
# ['FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'REAL',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
#  'FAKE',
# ...

# %%
tfidf_vectorizer=TfidfVectorizer(stop_words='english', max_df=0.7)
#DataFlair - Fit and transform train set, transform test set
tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
tfidf_test=tfidf_vectorizer.transform(x_test)

# %%
#DataFlair - Initialize a PassiveAggressiveClassifier
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(tfidf_train,y_train)

#DataFlair - Predict on the test set and calculate accuracy
y_pred=pac.predict(tfidf_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 97.34%

# %%
#DataFlair - Build confusion matrix
confusion_matrix(y_test,y_pred, labels=['FAKE','REAL'])
# Out:
# array([[670,   3],
#        [ 17,  62]], dtype=int64)

# %%
# %config Completer.use_jedi = False

# %%
browser.find_element_by_class_name('close-icon').click()

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
WebDriverWait(browser, 20).until(EC.element_to_be_clickable(By.ID, 'closeXButton'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-8c5ee09c219d> in <module>
#       2 from selenium.webdriver.common.by import By
#       3 from selenium.webdriver.support import expected_conditions as EC
# ----> 4 WebDriverWait(browser, 20).until(EC.element_to_be_clickable(By.ID, 'closeXButton'))
#
# TypeError: __init__() takes 2 positional arguments but 3 were given

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

browser = webdriver.Firefox()
browser.get('https://www.poynter.org/ifcn-covid-19-misinformation/?covid_countries=0&covid_rating=51174&covid_fact_checkers=0')
data_list = []

time.sleep(10)
try:
    if browser.find_element_by_class_name('draggable-container'):

        browser.find_element_by_class_name('close-icon').click()
except NoSuchElementException:
        pass
    

    
for j in range(15*15):
    for i in browser.find_elements_by_class_name('entry-title'):
        data_list.append(i.text[6:])
    try:    
        browser.find_element_by_class_name('next').click()
    except NoSuchElementException:
        browser.quit()
browser.quit()

# %%
for i in range(len(data_list)):
    data_list[i] = data_list[i].strip()

# %%
data_list
# Out:
# ['Covid-19 masks are dangerous and the obligation to wear them is a crime against humanity',
#  'Thousands of people demonstrate in Romania against health measures',
#  'The Argentine Vice President, Cristina Fernández de Kirchner, was “multi-vaccinated” against the coronavirus, as shown in these three images',
#  'Fernando Simón, director of the Center for the Coordination of Health Alerts and Emergencies of the Spanish Ministry of Health, has recognized that deaths from other causes are included as if they were from COVID-19',
#  'News from the newspaper ‘El País’ in the year 2003 about the current COVID-19 pandemic',
#  'World Health Organization (WHO) approved Coronil, an Indian herbal medication, as a Covid-19 treatment.',
#  'The Province of Buenos Aires (Argentina) has already finished vaccinating all its health personnel',
#  'The Corona Virus vaccine “can leave you sterile,” according to Argentine actor Marcelo Mazzarello',
# ...

# %%
flse_lst = [False]*len(data_list)

# %%
flse_lst
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
import pandas as pd

# %%
file = pd.DataFrame({'text':data_list,
             'label':flse_lst})

# %%
file
# Out:
#                                                    text  label
# 0     Covid-19 masks are dangerous and the obligatio...  False
# 1     Thousands of people demonstrate in Romania aga...  False
# 2     The Argentine Vice President, Cristina Fernánd...  False
# 3     Fernando Simón, director of the Center for the...  False
# 4     News from the newspaper ‘El País’ in the year ...  False
# ...                                                 ...    ...
# 3370  A female overseas Filipino worker (OFW) in Sau...  False
# 3371  Migrants traveling to their homes from Mumbai ...  False
# 3372  Bill Gates, Melinda Gates, Anthony Fauci and t...  False
# 3373  In Italy, the cure for Coronavirus is finally ...  False
# 3374  A video which would show that the Immuni app (...  False
#
# [3375 rows x 2 columns]

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

browser = webdriver.Firefox()
browser.get('https://www.indiatoday.in/coronavirus-outbreak/vaccine-updates')
true_list = []


    
for j in range(16):
    for i in browser.find_elements_by_class_name('detail'):
        true_list.append(i.text.replace('\n',' ').strip().rstrip())
    try:    
        if browser.find_element_by_class_name('pager-next'):
            browser.find_element_by_class_name('pager-next').click()
    except NoSuchElementException:
        browser.quit()
        break
browser.quit()

# %%
true_list
# Out:
# ["Cost of vaccinating Indians above 18 years less than 1% of annual GDP: Study The study conducted by India Ratings has come out at a time when the Centre and states are engaged in an argument over the pricing difference of Covid-19 vaccines. The study has estimated the cost of vaccinating all Indians above the age of 18 years at just 0.36 per cent of India's annual GDP.",
#  'Covid-19 vaccination registration for those above 18 to begin from April 28: Centre Vaccine registrations for all those above 18 years will commence on the CoWIN platform and Aarogya Setu app from April 28, the Centre said on Thursday.',
#  "Pfizer offers to supply Covid-19 vaccine at 'not-for-profit' rate to Indian govt US-based pharmaceutical company Pfizer has offered to supply its Covid-19 vaccine at the 'not-for-profit' rate to the Indian government.",
# ...

# %%
tr = [True]*len(true_list)

# %%
fl = pd.DataFrame({'text':true_list,
             'label':tr})

# %%
file = file.append(fl)

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

browser = webdriver.Firefox()
browser.get('https://timesofindia.indiatimes.com/india/coronavirus-lockdown-in-india-covid-19-vaccine-cases-live-updates-21-april-2021/liveblog/82169052.cms')

time.sleep(5)

browser.find_element_by_class_name('ntfc_dactive').click()

n = None
while True:
    try:
        browser.find_element_by_xpath('/html/body/div[2]/div/div[4]/div[2]/div[4]/div[1]/div/div[2]/div[2]/button').click()
    except NoSuchElementException:
        n = browser.find_elements_by_class_name('_2ndvO').copy()
        break


tru = []
for i in n:
    tru.append(i.text[18:].replace('\n',' ').strip())

# %%
tru
# Out:
# ['Chhattisgarh CM writes to PM seeking immediate information on availability and cost of Covid-19 vaccines to be provided as part of 3rd phase of vaccination drive commencing May 1',
#  'States should come down heavily on hoarding of oxygen: PM at review meeting over oxygen supply and availability',
#  'Ensure oxygen supply to states in smooth, unhindered manner; fix responsibility with local administration in cases of obstruction, PM says',
#  'Oxygen review meeting: PM Modi calls for using innovative ways to provide oxygen support to health facilities',
#  'ORIES Pilots association urges DGCA to suspend breath analyser test amid Covid threat ‘India has enough oxygen, but transport a problem’ Let’s define essential list: Industry Covid-19: India Inc scrambles to get staff vaccinated READ MORE STORIES',
#  'Officials brief PM on efforts undertaken to improve oxygen supply; PM calls for increasing production and speed of distribution',
# ...

# %%
tli = [True] * len(tru)

# %%
file = file.append(pd.DataFrame({'text':tru,
             'label':tli}))

# %%
file.to_csv('fakenew.csv', index=False)

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

browser = webdriver.Firefox()
browser.get('https://www.bbc.com/news/coronavirus')

n = None

# %%
browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
browser.find_element_by_class_name('lx-pagination__btn').click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-41-6a42d21f466b> in <module>
#       1 browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# ----> 2 browser.find_element_by_class_name('lx-pagination__btn').click()
#
# ~\anaconda3\envs\machine_learning\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\envs\machine_learning\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
n = browser.find_elements_by_class_name('qa-heading-link').copy()
